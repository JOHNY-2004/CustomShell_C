# %% [markdown]
# <a href="https://colab.research.google.com/github/JOHNY-2004/CustomShell_C/blob/main/Project7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6029233d-e2ee-4af5-bfee-24874df2cf69" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6029233d-e2ee-4af5-bfee-24874df2cf69">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d imenmasmoudi/acdc-dataset-from-the-miccai
# Out:
# Dataset URL: https://www.kaggle.com/datasets/imenmasmoudi/acdc-dataset-from-the-miccai
# License(s): apache-2.0
# ...
#  99% 1.59G/1.61G [00:18<00:00, 191MB/s]
# 100% 1.61G/1.61G [00:18<00:00, 95.0MB/s]

# %%
# !unzip \*.zip -d ./dataset
# Out:
# Archive:  acdc-dataset-from-the-miccai.zip
#   inflating: ./dataset/ACDC/database/MANDATORY_CITATION.md
#   inflating: ./dataset/ACDC/database/testing/MANDATORY_CITATION.md
#   inflating: ./dataset/ACDC/database/testing/patient101/Info.cfg
#   inflating: ./dataset/ACDC/database/testing/patient101/MANDATORY_CITATION.md
#   inflating: ./dataset/ACDC/database/testing/patient101/patient101_4d.nii
#   inflating: ./dataset/ACDC/database/testing/patient101/patient101_frame01.nii
#   inflating: ./dataset/ACDC/database/testing/patient101/patient101_frame01_gt.nii
#   inflating: ./dataset/ACDC/database/testing/patient101/patient101_frame14.nii
#   inflating: ./dataset/ACDC/database/testing/patient101/patient101_frame14_gt.nii
#   inflating: ./dataset/ACDC/database/testing/patient102/Info.cfg
#   inflating: ./dataset/ACDC/database/testing/patient102/MANDATORY_CITATION.md
#   inflating: ./dataset/ACDC/database/testing/patient102/patient102_4d.nii
# ...
